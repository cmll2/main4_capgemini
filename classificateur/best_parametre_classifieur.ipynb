# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier, LinearDiscriminantAnalysis
from sklearn.metrics import accuracy_score
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV, StratifiedKFold, RandomizedSearchCV
from joblib import parallel_backend
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In [29], line 6
#       4 from sklearn.model_selection import cross_val_score
#       5 from sklearn.model_selection import train_test_split
# ----> 6 from sklearn.neural_network import MLPClassifier, LinearDiscriminantAnalysis
#       7 from sklearn.metrics import accuracy_score
#       8 from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
#
# ImportError: cannot import name 'LinearDiscriminantAnalysis' from 'sklearn.neural_network' (/home/portable014/.local/lib/python3.8/site-packages/sklearn/neural_network/__init__.py)

# %%
dataset = pd.read_csv('/home/portable014/Bureau/neelp_1/MAIN_4_PC/Projet/main4_capgemini/pre-traitement/données/stockage_csv_non_normalized/13_adresse_dormir.csv')
#le path est à changer en fonction de l'endroit où on a mis le fichier csv
#ici, il prend un csv pré-enregistré avec 2 mots différents
nb_mots = 13
dataset =dataset.fillna(0) 


y = dataset[['class']] # vecteur colonne contenant la classe (= le nom du mot)
X = dataset.iloc[:, 1:6001] # matrice contenant toutes les coordonnées d'une vidéo 

#on split les données en données d'entrainements : X_train, y_train et en données de test : X_test et y_test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=27, stratify= y) #on séépare les données en 2 parties : 25% pour le test et 75% pour l'entrainement
#strategy = y permet de garder la même proportion de chaque classe dans les données d'entrainement et de test
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [21], line 1
# ----> 1 dataset = pd.read_csv('/home/portable014/Bureau/neelp_1/MAIN_4_PC/Projet/main4_capgemini/pre-traitement/données/stockage_csv_non_normalized/13_adresse_dormir.csv')
#       2 #le path est à changer en fonction de l'endroit où on a mis le fichier csv
#       3 #ici, il prend un csv pré-enregistré avec 2 mots différents
#       4 nb_mots = 13
#
# File ~/.local/lib/python3.8/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
# ...

# %% [markdown]
# ## KNN

# %%
# Liste de différentes valeurs de leaf_size à tester
leaf_sizes = [1, 5, 10, 15, 20, 25, 30, 40, 50]

# Tableau pour stocker les précisions pour chaque valeur de leaf_size
scores = []

for leaf_size in leaf_sizes:
    knn = KNeighborsClassifier(leaf_size=leaf_size)
    score = np.mean(cross_val_score(knn, X_train, y_train, cv=5, scoring='accuracy'))
    scores.append(score)

# Recherche de la meilleure précision et de son index correspondant
best_index = np.argmax(scores)
best_leaf_size = leaf_sizes[best_index]
best_score = scores[best_index]

print("Le meilleur leaf_size est:", best_leaf_size)
print("La meilleure précision est:", best_score)

# %% [markdown]
# ## MPL

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import GridSearchCV, StratifiedKFold, RandomizedSearchCV
from joblib import parallel_backend


# Define the hyperparameters to search
param_grid = {'hidden_layer_sizes': [(10,), (50,), (100,), (10, 10), (50, 50)],
              'activation': ['logistic', 'tanh', 'relu'],
              'alpha': [0.0001, 0.001, 0.01, 0.1]}

# Instantiate an MLPClassifier
mlp = MLPClassifier()

# # Create a StratifiedKFold object
# cv = StratifiedKFold(n_splits=2)

# Create a GridSearchCV object with n_jobs=-1 and cv=cv
grid_search = RandomizedSearchCV(estimator=mlp, cv=None, n_jobs=-1, n_iter=10, param_distributions = param_grid)

# Use parallel_backend to set the backend to 'multiprocessing'
with parallel_backend('multiprocessing'):
    # Fit the GridSearchCV object to the data
    grid_search.fit(X_train, y_train)

# Print the best parameters and best score
print(f"Best Parameters: {grid_search.best_params_}")
print(f"Best Score: {grid_search.best_score_}")

# %% [markdown]
# ## SGDC

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import GridSearchCV, StratifiedKFold, RandomizedSearchCV
from joblib import parallel_backend
from scipy.stats import loguniform

# Define the hyperparameters to search
param_dist = {'alpha': loguniform(1e-5, 1e0),
              'l1_ratio': [0, 0.25, 0.5, 0.75, 1],
              'penalty': ['l1', 'l2', 'elasticnet'],
              'max_iter': [1000, 2000, 5000]}

# Instantiate an SGDClassifier
sgd = SGDClassifier()

# Create a RandomizedSearchCV object
random_search = RandomizedSearchCV(estimator=sgd, param_distributions=param_dist, n_iter=100, cv=5, random_state=42)

# Use parallel_backend to set the backend to 'multiprocessing'
with parallel_backend('multiprocessing'):
    # Fit the RandomizedSearchCV object to the data
    random_search.fit(X, y)

# Print the best parameters and best score
print(f"Best Parameters: {random_search.best_params_}")
print(f"Best Score: {random_search.best_score_}")
# Out:
# /home/portable014/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/portable014/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/portable014/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %% [markdown]
# ## LDA

# %%
# Load dataset
iris = load_iris()
X, y = iris.data, iris.target

# Define the hyperparameters to search
param_grid = {'solver': ['svd', 'lsqr', 'eigen'],
              'shrinkage': [None, 'auto', 0.1, 0.5, 0.9]}

# Instantiate an LDA classifier
lda = LinearDiscriminantAnalysis()

# Create a GridSearchCV object
grid_search = GridSearchCV(estimator=lda, param_grid=param_grid, cv=5)

# Fit the GridSearchCV object to the data
grid_search.fit(X, y)

# Print the best parameters and best score
print(f"Best Parameters: {grid_search.best_params_}")
print(f"Best Score: {grid_search.best_score_}")
# Out:
# /home/portable014/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# ## LR

# %%
# Définir les paramètres à tester
penalties = ['l1', 'l2']
C_values = [0.001, 0.01, 0.1, 1, 10, 100, 1000]
random_states = [0, 42, np.random.randint(1000)]

# Boucle sur les différentes combinaisons de paramètres
best_score = 0
best_params = None
for penalty in penalties:
    for C in C_values:
        for random_state in random_states:
            # Entraîner le classifieur LR avec les paramètres actuels
            clf = LogisticRegression(penalty=penalty, C=C, random_state=random_state)
            clf.fit(X_train, y_train)
            
            # Évaluer la performance sur les données de test
            y_pred = clf.predict(X_test)
            score = accuracy_score(y_test, y_pred)
            
            # Enregistrer les paramètres ayant les meilleures performances
            if score > best_score:
                best_score = score
                best_params = {'penalty': penalty, 'C': C, 'random_state': random_state}

# Imprimer les meilleurs paramètres
print("Meilleurs paramètres: ", best_params)
print("Score: ", best_score)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [4], line 2
#       1 # Charger les données
# ----> 2 data = pd.read_csv("votre_fichier_de_données.csv")
#       3 X = data.drop("étiquette_à_prédire", axis=1).values
#       4 y = data["étiquette_à_prédire"].values
#
# File ~/.local/lib/python3.8/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
# ...
