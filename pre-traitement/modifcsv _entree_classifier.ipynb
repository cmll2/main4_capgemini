# %%
import mediapipe as mp  # Import mediapipe
import cv2  # Import opencv
import csv
import os
import numpy as np
import sklearn
import pandas as pd
import csv

# %%
#Création d'un fichier à partir de la liste tableau
with open('modif.csv','w',newline='') as f: 
    tableau=[]                                #Ouverture du fichier CSV en écriture
    ecrire=csv.writer(f)                        # préparation à l'écriture
    for i in tableau:                           # Pour chaque ligne du tableau...  
        ecrire.writerow(i)                # Mettre dans la variable ecrire cette nouvelle ligne      
print('',end='\n')
print('longueur du tableau : ',len(tableau))
# Out:
# longueur du tableau :  0

# %%
#Ajout d'une ligne

liste = []
with open('modif.csv','a',newline='') as f:       #Ajout d'une ligne dans le fichier csv
    ecrire=csv.writer(f) 
    for i in range(1,76):
        for j in range (1,24):
            mot='x' + str (i) + '_' + str(j)
            liste.append(mot ) 
        
        for j in range (1,24):
            mot2='y' + str (i) + '_' + str(j)
            liste.append(mot2 ) 
        
        for j in range (1,24):
            mot3='z' + str (i) + '_' + str(j)
            liste.append(mot3 )
        
        for j in range (1,24):
            mot4='v' + str (i) + '_' + str(j)
            liste.append(mot4 )





with open('modif.csv','a',newline='') as f:       #Ajout d'une ligne dans le fichier csv
    ecrire=csv.writer(f)                             # préparation à l'écriture   
    ecrire.writerow(['label', 'class' ]+ liste) 

#with open('modif.csv','a',newline='') as f:       #on remplit les données
#    ecrire=csv.writer(f)                             # préparation à l'écriture   
#    for i in range (1,76):
#        for j in range (1,24):
#            ecrire.writerow()               
            #ecrire.writerow()

#print(liste)

# %%
with open('coords.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        tab=row['x1']
        print(row['x1'])
        for i in range(1,len(tab)):
            with open('modif.csv','w',newline='') as f:
                ecrire=csv.writer(f) 
                ecrire.writerow(tab[i])

print(len(row['x1']))
# Out:
# 0.5628101825714111
# 0.5626869797706604
# 0.562817394733429
# 0.5628172755241394
# 0.5627570152282715
# 0.5628048777580261
# 0.5628269910812378
# 0.5633851885795593
# 0.5633825659751892
# 0.5622233748435974
# 0.5617227554321289
# 0.561707615852356
# 0.5616676211357117
# 0.5616129040718079
# 0.5616474151611328
# 0.5613057613372803
# 0.5612849593162537
# 0.5616472959518433
# 0.5621703267097473
# 0.5631476640701294
# 0.5631883144378662
# 0.5634009838104248
# 0.5635586977005005
# 0.5636464953422546
# 0.5636852383613586
# 0.5634920001029968
# 0.5626523494720459
# 0.5421819686889648
# 0.5422249436378479
# 0.5424038171768188
# 0.542138397693634
# 0.5418106317520142
# 0.5417128205299377
# 0.5420176982879639
# 0.5423334240913391
# 0.5421991944313049
# 0.5423268675804138
# 0.5422943234443665
# 0.5417080521583557
# 0.5413972735404968
# 0.5413838028907776
# 0.5411543846130371
# 0.5411983728408813
# 0.5414730310440063
# 0.5436409115791321
# 0.5453702211380005
# 0.5458062291145325
# 0.5459674000740051
# 0.5427470207214355
# 0.5427575707435608
# 0.5425869822502136
# 0.5337223410606384
# 0.534602165222168
# 0.5350332856178284
# 0.5350210070610046
# 0.5344306826591492
# 0.5342646837234497
# 0.534152090549469
# 0.5353957414627075
# 0.5372344255447388
# 0.5384874939918518
# 0.5397347807884216
# 0.5407230854034424
# 0.5415825843811035
# 0.5418421030044556
# 0.5419055819511414
# 18

# %%
import pandas
my_file = pandas.read_csv('coords.csv', sep=",")

list_x1 = my_file['x1'][0:20]
list_x2 = my_file['x2'][0:20]
read.csv
print(list_x1)
# Out:
# 0     0.562810
# 1     0.562687
# 2     0.562817
# 3     0.562817
# 4     0.562757
# 5     0.562805
# 6     0.562827
# 7     0.563385
# 8     0.563383
# 9     0.562223
# 10    0.561723
# 11    0.561708
# 12    0.561668
# 13    0.561613
# 14    0.561647
# 15    0.561306
# 16    0.561285
# 17    0.561647
# 18    0.562170
# 19    0.563148
# Name: x1, dtype: float64

# %%
import pandas

my_file = pandas.read_csv("/home/portable014/Bureau/neelp_1/MAIN_4_PC/CapGemini_perso/coords.csv", sep=",")
my_columns = pandas.read_csv("/home/portable014/Bureau/neelp_1/MAIN_4_PC/CapGemini_perso/modif.csv", sep=",")

header = list(my_columns.head())

list_x1 = list(my_file['x1'][:20])
list_x2 = list(my_file['x2'][:20])

header
## Création d'une grande liste 
data = list_x1+list_x2
print(data)
## Création d'une dataframe pandas.Dataframe() 

#df = pandas.DataFrame(data, columns=header[:len(data)])
df = pd.DataFrame(columns=header[:len(data)], index=['1'])
df.loc['1'] = data
## Enregistrer csv
df
#df.to_csv("", sep = ",")
# Out:
# [0.5628101825714111, 0.5626869797706604, 0.562817394733429, 0.5628172755241394, 0.5627570152282715, 0.5628048777580261, 0.5628269910812378, 0.5633851885795593, 0.5633825659751892, 0.5622233748435974, 0.5617227554321289, 0.561707615852356, 0.5616676211357117, 0.5616129040718079, 0.5616474151611328, 0.5613057613372803, 0.5612849593162537, 0.5616472959518433, 0.5621703267097473, 0.5631476640701294, 0.581306517124176, 0.5812987685203552, 0.5813034772872925, 0.5813505053520203, 0.5813477039337158, 0.5814213752746582, 0.5814467072486877, 0.5817067623138428, 0.5817126631736755, 0.5806912779808044, 0.5802398920059204, 0.5801687836647034, 0.5799484848976135, 0.5797182321548462, 0.5798359513282776, 0.5796607136726379, 0.579669177532196, 0.5800793170928955, 0.5806416273117065, 0.5815603733062744]
#      label     class      x1_1      x1_2      x1_3      x1_4      x1_5  \
# 1  0.56281  0.562687  0.562817  0.562817  0.562757  0.562805  0.562827
#
#        x1_6      x1_7      x1_8  ...     y1_6      y1_7      y1_8      y1_9  \
# 1  0.563385  0.563383  0.562223  ...  0.58024  0.580169  0.579948  0.579718
#
#       y1_10     y1_11     y1_12     y1_13     y1_14    y1_15
# 1  0.579836  0.579661  0.579669  0.580079  0.580642  0.58156
#
# [1 rows x 40 columns]
